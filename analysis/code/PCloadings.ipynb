# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from jupyterthemes import jtplot
jtplot.style(context='paper', fscale=1)
df=pd.read_csv('/data/dataDB/WIN_Matter/analysis/data/WINPCload.csv')

# %%
#setting up colors for each health variable
#body measures: blue 
#body fat: green
#cardiorespiratory measures: purple
health=df.HealthVariables.unique().tolist()
health_colors=["#609CE1","#236AB9","#133863","#9BD770", "#66B032","#5A18C9","#905BEC"]
color_dict=dict(zip(health, health_colors))
sns.set_context=("poster")
plt.ylim(-.5, 1)
#sns.set(rc={'figure.figsize':(25,30)})
ax=sns.barplot(x="PC Variables", y="Loading(corr)", hue="HealthVariables", data=df, palette=color_dict)
#plt.legend(loc=fontsize='large')
#ax.set_ylabel("Loading(corr)",fontsize=15)
#ax.set_xlabel("PC Variables", fontsize=15)
ax.get_figure().savefig("/data/dataDB/WIN_Matter/analysis/output/images/pcaBarplots.png")
