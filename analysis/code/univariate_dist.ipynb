# %%
import pandas as pd
import numpy as np
import seaborn as sns
import ptitprince as pt
import matplotlib.pyplot as plt
import matplotlib.collections as clt
from jupyterthemes import jtplot
pc1_great=pd.read_csv('~/Google Drive/WIN_Matter/analysis/data/PC1_greater_coef.csv', index_col=0)
pc1_less=pd.read_csv('~/Google Drive/WIN_Matter/analysis/data/PC1_lesser_coef.csv', index_col=0)
#pc1_great_alone=pd.read_csv('/Users/aporter1350/Google Drive/WIN_Matter/analysis/data/PC1_greater_alone_coef.csv', index_col=0)
#pc1_less_alone=pd.read_csv('/data/pc1_lesser_alone_coef.csv', index_col=0)
pc2_great=pd.read_csv('~/Google Drive/WIN_Matter/analysis/data/PC2_greater_coef.csv', index_col=0)
pc2_less=pd.read_csv('~/Google Drive/WIN_Matter/analysis/data/PC2_lesser_coef.csv', index_col=0)
#pc2_great_alone=pd.read_csv('/data/pc2_greater_alone_coef.csv', index_col=0)
#pc2_less_alone=pd.read_csv('/data/pc2_lesser_alone_coef.csv', index_col=0)

# %%
#pt.RainCloud(x=pc1_great['PC1_greater'], orient="h")
#pt.RainCloud(x=pc1_less['PC1_lesser'], orient="h")
#pt.RainCloud(x=pc2_great['PC2_greater'], orient="h")
#pt.RainCloud(x=pc2_less['PC2_lesser'], orient="h")

# %%
#sns.violinplot(x=pc1_less['psig'], y=pc1_less['PC1_lesser'], figsize=(8,8))
#plt.savefig('/data/dataDB/WIN_Matter/analysis/output/images/PC1_lesser_psig_comparison.png', bbox_inches='tight')
sns.set_context=("talk")
pc1_less_sig=pc1_less.loc[pc1_less['psig']==1]
pc1_less_sig=pc1_less_sig.loc[pc1_less_sig['PC1_lesser']<0]
ax=pt.RainCloud(x=pc1_less_sig['PC1_lesser'], orient="h")
ax.set_xlabel('$\Delta QA$', fontsize=20)
ax.set_title('Significant Fibers from PC1(-) Mask', fontsize=20)
plt.savefig('/Users/aporter1350/Google Drive/WIN_Matter/analysis/output/images/PC1_lesser_psig.png', bbox_inches='tight')
#pc1_less_sig.to_csv('/data/dataDB/WIN_Matter/analysis/data/PC1_less_sigOnly_fibers_list.csv')

# %%
#sns.violinplot(x=pc1_great['psig'], y=pc1_great['PC1_greater'], figsize=(8,8))
#plt.savefig('/data/dataDB/WIN_Matter/analysis/output/images/PC1_greater_psig_comparison.png', bbox_inches='tight')
pc1_great_sig=pc1_great.loc[pc1_great['psig']==1]
pc1_great_sig=pc1_great_sig.loc[pc1_great_sig['PC1_greater']>0]
ax=pt.RainCloud(x=pc1_great_sig['PC1_greater'], orient="h")
ax.set_xlabel('$\Delta QA$', fontsize=20)
ax.set_title('Significant Fibers from PC1(+) Mask', fontsize=20)
plt.savefig('/Users/aporter1350/Google Drive/WIN_Matter/analysis/output/images/PC1_greater_psig.png', bbox_inches='tight')
#pc1_great_sig.to_csv('/data/dataDB/WIN_Matter/analysis/data/PC1_great_sigOnly_fibers_list.csv')

# %%
#sns.violinplot(x=pc1_less_alone['psig'], y=pc1_less_alone['PC1_lesser'], figsize=(8,8))
#plt.savefig('pc1_lesser_alone_psig_comparison.png', bbox_inches='tight')
#pc1_less_sig_alone=pc1_less_alone.loc[pc1_less_alone['psig']==1]
#ax=pt.RainCloud(x=pc1_less_sig_alone['PC1_lesser'], orient="h")
#plt.savefig('pc1_lesser_alone_psig.png', bbox_inches='tight')

# %%
#sns.violinplot(x=pc1_great_alone['psig'], y=pc1_great_alone['PC1_greater'], figsize=(8,8))
#plt.savefig('pc1_greater_alone_psig_comparison.png', bbox_inches='tight')
#pc1_great_sig_alone=pc1_great_alone.loc[pc1_great_alone['psig']==1]
#ax=pt.RainCloud(x=pc1_great_sig_alone['PC1_greater'], orient="h")
#plt.savefig('pc1_greater_alone_psig.png', bbox_inches='tight')

# %%
#sns.violinplot(x=pc2_great['psig'], y=pc2_great['PC2_greater'], figsize=(8,8))
#plt.savefig('/data/dataDB/WIN_Matter/analysis/output/images/PC2_greater_psig_comparison.png', bbox_inches='tight')
pc2_great_sig=pc2_great.loc[pc2_great['psig']==1]
pc2_great_sig=pc2_great_sig.loc[pc2_great_sig['PC2_greater']>0]
ax=pt.RainCloud(x=pc2_great_sig['PC2_greater'], orient="h")
ax.set_xlabel('$\Delta QA$', fontsize=20)
ax.set_title('Significant Fibers from PC2(+) Mask', fontsize=20)
plt.savefig('/Users/aporter1350/Google Drive/WIN_Matter/analysis/output/images/PC2_greater_psig.png', bbox_inches='tight')
#pc2_great_sig.to_csv('/data/dataDB/WIN_Matter/analysis/data/PC2_great_sigOnly_fibers_list.csv')

# %%
#sns.violinplot(x=pc2_less['psig'], y=pc2_less['PC2_lesser'], figsize=(8,8))
#plt.savefig('/data/dataDB/WIN_Matter/analysis/output/images/PC2_lesser_psig_comparison.png', bbox_inches='tight')
pc2_less_sig=pc2_less.loc[pc2_less['psig']==1]
pc2_less_sig=pc2_less_sig.loc[pc2_less_sig['PC2_lesser']<0]
ax=pt.RainCloud(x=pc2_less_sig['PC2_lesser'], orient="h")
ax.set_xlabel('$\Delta QA$', fontsize=20)
ax.set_title('Significant Fibers from PC2(-) Mask', fontsize=20)
plt.savefig('/Users/aporter1350/Google Drive/WIN_Matter/analysis/output/images/PC2_lesser_psig.png', bbox_inches='tight')
#pc2_less_sig.to_csv('/data/dataDB/WIN_Matter/analysis/data/PC2_less_sigOnly_fibers_list.csv')

# %%
pwd
# Out:
# '/Users/aporter1350/Google Drive/WIN_Matter/analysis/code'
